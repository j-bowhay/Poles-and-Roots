# %%
import matplotlib.pyplot as plt

from poles_roots.global_zero_pole import find_zeros_poles
from poles_roots import reference_problems
from poles_roots.plotting import phase_plot, plot_poles_zeros

# %% [markdown]
# ## Reference Problem 1:
#
# \begin{equation}
# f(z) = \frac{1}{z - 0.5}
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func0,
    reference_problems.func0_jac,
    points=[-9.9 - 10j, 10 - 10j, 10 + 10j, -10 + 10j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func0, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func0, axs[1], domain=[-11, 11, -11, 11])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()

# %% [markdown]
# ## Reference Problem 2:
#
# \begin{equation}
# f(z) = z-2
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func1,
    reference_problems.func1_jac,
    points=[-9.9 - 10j, 10 - 10j, 10 + 10j, -10 + 10j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func1, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func1, axs[1], domain=[-11, 11, -11, 11])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()

# %% [markdown]
# ## Reference Problem 3:
#
# \begin{equation}
# f(z) = \exp(3z) + 2z\cos(z) - 1
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func2,
    reference_problems.func2_jac,
    points=[-9 - 9.2j, 9 - 10j, 9.9 + 9.8j, -9.3 + 9.5j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func2, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func2, axs[1], domain=[-10, 10, -10, 10])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()

# %% [markdown]
# ## Reference Problem 4:
#
# \begin{equation}
# f(z) = z^2(z - 1)(z - 2)(z - 3)(z - 4) + z\sin(z)
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func3,
    reference_problems.func3_jac,
    points=[-9 - 9.2j, 9 - 10j, 9.9 + 9.8j, -9.3 + 9.5j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func3, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func3, axs[1], domain=[-10, 10, -10, 10])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()
# Out:
# /home/jakeb/development/poles-and-roots/venv/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:449: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   im_retval = quad(imfunc, a, b, args, full_output, epsabs,
# AAA and argument principle don't match: aaa_z_minus_p=0, arg_princ_z_minus_p=(0.9989561213525641-2.3092638912203256e-13j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(1.0010438786474365+3.5927017654271975e-13j)

# %% [markdown]
# ## Reference Problem 5:
#
# \begin{equation}
# f(z) = z^2(z - 2)^2(z^3 + \exp(2z)\cos(z) - \sin(z) - 1)
# \end{equation}
#
# TRIANGULATION FAILS FOR THIS PROBLEM

# %%
res = find_zeros_poles(
    reference_problems.func4,
    reference_problems.func4_jac,
    points=[-9 - 9.2j, 8 - 10j, 9.9 + 9.8j, -9.3 + 9.5j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func4, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func4, axs[1], domain=[-10, 10, -10, 10])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()
# Out:
# /home/jakeb/development/poles-and-roots/venv/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:449: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   im_retval = quad(imfunc, a, b, args, full_output, epsabs,
# /home/jakeb/development/poles-and-roots/venv/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:446: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   re_retval = quad(refunc, a, b, args, full_output, epsabs,
# /home/jakeb/development/poles-and-roots/venv/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:449: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   im_retval = quad(imfunc, a, b, args, full_output, epsabs,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 res = find_zeros_poles(
#       2     reference_problems.func4,
#       3     reference_problems.func4_jac,
#       4     points=[-9 - 9.2j, 8 - 10j, 9.9 + 9.8j, -9.3 + 9.5j],
#       5     arg_principal_threshold=1.1,
#       6     num_sample_points=50,
#       7 )
#       9 fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
#      10 phase_plot(reference_problems.func4, axs[0], domain=[-10, 10, -10, 10])
#
# File ~/development/poles-and-roots/src/poles_roots/global_zero_pole.py:59, in find_zeros_poles(f, f_jac, points, num_sample_points, arg_principal_threshold, quad_kwargs)
#      32 """Compute all the zeros and pole of `f`
#      33
#      34 Parameters
#    (...)
#      56     _description_
#      57 """
#      58 # triangulate the domain
# ---> 59 points, simplices, arg_princ_z_minus_ps = adaptive_triangulation(
#      60     f, f_jac, points, arg_principal_threshold, quad_kwargs
#      61 )
#      63 poles = []
#      64 residuals = []
#
# File ~/development/poles-and-roots/src/poles_roots/triangulation.py:27, in adaptive_triangulation(f, f_jac, initial_points, arg_principal_threshold, plot, quad_kwargs)
#      20 points = np.column_stack([initial_points.real, initial_points.imag])
#      21 tri = scipy.spatial.Delaunay(points, incremental=True)
#      23 while np.any(
#      24     (
#      25         to_insert := np.abs(
#      26             (
# ---> 27                 z_minus_p := argument_priciple_of_triangulation(
#      28                     f,
#      29                     f_jac,
#      30                     tri.points,
#      31                     tri.simplices,
#      32                     quad_kwargs,
#      33                 )
#      34             ),
#      35         )
#      36         > arg_principal_threshold
#      37     ),
#      38 ):
#      39     if plot:
#      40         fig, ax = plt.subplots()
#
# File ~/development/poles-and-roots/src/poles_roots/integration.py:91, in argument_priciple_of_triangulation(f, f_jac, points, simplices, quad_kwargs)
#      89 for i, simplex in enumerate(simplices):
#      90     simplex_points = convert_cart_to_complex(points[simplex])
# ---> 91     result[i] = argument_principle_from_points(
#      92         f,
#      93         f_jac,
#      94         simplex_points,
#      95         quad_kwargs,
#      96     )
#      97 return result
#
# File ~/development/poles-and-roots/src/poles_roots/integration.py:68, in argument_principle_from_points(f, f_jac, points, quad_kwargs)
#      64     b = np.take(points, i + 1, mode="wrap")
#      66     param, param_jac = parametrise_between_two_points(a, b)
# ---> 68     res += argument_principle_from_parametrisation(
#      69         f,
#      70         f_jac,
#      71         param,
#      72         param_jac,
#      73         (0, 1),
#      74         quad_kwargs=quad_kwargs,
#      75     )
#      77 return res
#
# File ~/development/poles-and-roots/src/poles_roots/integration.py:45, in argument_principle_from_parametrisation(f, f_jac, param, param_jac, limits, quad_kwargs)
#      42 def _f(t):
#      43     return f_jac(t) / f(t)
# ---> 45 return complex_integration(
#      46     _f,
#      47     param,
#      48     param_jac,
#      49     limits,
#      50     quad_kwargs=quad_kwargs,
#      51 ) / (2 * np.pi * 1j)
#
# File ~/development/poles-and-roots/src/poles_roots/integration.py:29, in complex_integration(f, param, param_jac, limits, quad_kwargs)
#      25         return f(param(t)) * param_jac
#      27 quad_kwargs = {} if quad_kwargs is None else quad_kwargs
# ---> 29 return scipy.integrate.quad(_f, *limits, complex_func=True, **quad_kwargs)[0]
#
# File ~/development/poles-and-roots/venv/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:449, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     444     return func(x, *args).real
#     446 re_retval = quad(refunc, a, b, args, full_output, epsabs,
#     447                  epsrel, limit, points, weight, wvar, wopts,
#     448                  maxp1, limlst, complex_func=False)
# --> 449 im_retval = quad(imfunc, a, b, args, full_output, epsabs,
#     450                  epsrel, limit, points, weight, wvar, wopts,
#     451                  maxp1, limlst, complex_func=False)
#     452 integral = re_retval[0] + 1j*im_retval[0]
#     453 error_estimate = re_retval[1] + 1j*im_retval[1]
#
# File ~/development/poles-and-roots/venv/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:464, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     461     return retval
#     463 if weight is None:
# --> 464     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     465                    points)
#     466 else:
#     467     if points is not None:
#
# File ~/development/poles-and-roots/venv/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:611, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     609 if points is None:
#     610     if infbounds == 0:
# --> 611         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     612     else:
#     613         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     614                                 epsabs, epsrel, limit)
#
# File ~/development/poles-and-roots/venv/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:441, in quad.<locals>.imfunc(x, *args)
#     440 def imfunc(x, *args):
# --> 441     return func(x, *args).imag
#
# File ~/development/poles-and-roots/src/poles_roots/integration.py:25, in complex_integration.<locals>._f(t)
#      24 def _f(t):
# ---> 25     return f(param(t)) * param_jac
#
# File ~/development/poles-and-roots/src/poles_roots/integration.py:43, in argument_principle_from_parametrisation.<locals>._f(t)
#      42 def _f(t):
# ---> 43     return f_jac(t) / f(t)
#
# File ~/development/poles-and-roots/src/poles_roots/reference_problems.py:45, in func4(z)
#      40 def func4(z):
#      41     return (
#      42         z
#      43         * z
#      44         * np.square(z - 2)
# ---> 45         * (z * z * z + np.exp(2 * z) * np.cos(z) - np.sin(z) - 1)
#      46     )
#
# KeyboardInterrupt:

# %% [markdown]
# ## Reference Problem 6:
#
# \begin{equation}
# f(z) = (z - 1)(z - 2)(z - 3)(z - 4)(z - 5)(z - 6)(z - 7)(z - 8)(z - 9)(z - 10)
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func5,
    reference_problems.func5_jac,
    points=[-9 - 9.2j, 8 - 10j, 9.9 + 9.8j, -9.3 + 9.5j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func5, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func5, axs[1], domain=[-10, 10, -10, 10])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()
