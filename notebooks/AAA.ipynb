# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

from poles_roots.plotting import phase_plot, plot_poles_zeros
from poles_roots.aaa import AAA
from poles_roots import reference_problems

# %% [markdown]
# # AAA
#
# In this notebook we test AAA on a number of test problems.
#
# ## The Gamma Function
#
# First plot the original function:

# %%
fig, ax = plt.subplots()
im = phase_plot(scipy.special.gamma, ax, domain=[-10, 10, -10, 10])
fig.colorbar(im)

# %% [markdown]
# Now compare against AAA approximation. The original function has no zeros and poles at 0 and negative integers.

# %%
N = 500
Z = np.linspace(-5, 5, N)
F = scipy.special.gamma(Z)

r = AAA(F, Z, cleanup=False)

fig, ax = plt.subplots()
im = phase_plot(r, ax, domain=[-10, 10, -10, 10])
plot_poles_zeros(r, ax, expected_poles=list(range(0, -11, -1)))
ax.legend()
fig.colorbar(im)

# %% [markdown]
# ## Reference Problem 1:
#
# \begin{equation}
# f(z) = \frac{1}{z - 0.5}
# \end{equation}
#
# Original function:

# %%
fig, ax = plt.subplots()
im = phase_plot(reference_problems.func0, ax, domain=[-10, 10, -10, 10])
fig.colorbar(im)

# %% [markdown]
# Now compare against AAA approximation. The original function has no zeros and a pole at $z=0.5$.

# %%
F = reference_problems.func0(Z)

r = AAA(F, Z)

fig, ax = plt.subplots()
im = phase_plot(r, ax, domain=[-10, 10, -10, 10])
plot_poles_zeros(r, ax, expected_poles=[0.5])
ax.legend()
fig.colorbar(im)

# %% [markdown]
# ## Reference Problem 2:
#
# \begin{equation}
# f(z) = z-2
# \end{equation}
#
# Original function:

# %%
fig, ax = plt.subplots()
im = phase_plot(reference_problems.func1, ax, domain=[-10, 10, -10, 10])
fig.colorbar(im)

# %% [markdown]
# Now compare against AAA approximation. The original function has no poles and a zero at $z=2$.

# %%
Z = np.linspace(-5, 5, N)
F = reference_problems.func1(Z)

r = AAA(F, Z, cleanup=False)

fig, ax = plt.subplots()
im = phase_plot(r, ax, domain=[-10, 10, -10, 10])
plot_poles_zeros(r, ax, expected_zeros=[2])
ax.legend()
fig.colorbar(im)

# %% [markdown]
# ## Reference Problem 3:
#
# \begin{equation}
# f(z) = \exp(3z) + 2z\cos(z) - 1
# \end{equation}
#
# Original function:

# %%
fig, ax = plt.subplots()
im = phase_plot(reference_problems.func2, ax, domain=[-10, 10, -10, 10])
fig.colorbar(im)

# %% [markdown]
# Now compare against AAA approximation:

# %%
Z = np.linspace(-5, 5, N)
F = reference_problems.func2(Z)

r = AAA(F, Z, cleanup=False)

fig, ax = plt.subplots()
im = phase_plot(r, ax, domain=[-10, 10, -10, 10])
plot_poles_zeros(r, ax)
ax.legend()
fig.colorbar(im)

# %% [markdown]
# ## Reference Problem 4:
#
# \begin{equation}
# f(z) = z^2(z - 1)(z - 2)(z - 3)(z - 4) + z\sin(z)
# \end{equation}
#
# Original function:

# %%
fig, ax = plt.subplots()
im = phase_plot(reference_problems.func3, ax, domain=[-10, 10, -10, 10])
fig.colorbar(im)

# %% [markdown]
# Now compare against AAA approximation:

# %%
Z = np.linspace(-5, 5, N)
F = reference_problems.func3(Z)

r = AAA(F, Z, cleanup=False)

fig, ax = plt.subplots()
im = phase_plot(r, ax, domain=[-10, 10, -10, 10])
plot_poles_zeros(r, ax)
ax.legend()
fig.colorbar(im)

# %% [markdown]
# ## Reference Problem 5:
#
# \begin{equation}
# f(z) = z^2(z - 2)^2(z^3 + \exp(2z)\cos(z) - \sin(z) - 1)
# \end{equation}
#
# Original function:

# %%
fig, ax = plt.subplots()
im = phase_plot(reference_problems.func4, ax, domain=[-10, 10, -10, 10])
fig.colorbar(im)

# %% [markdown]
# Now compare against AAA approximation:

# %%
Z = np.linspace(-5, 5, N)
F = reference_problems.func4(Z)

r = AAA(F, Z, cleanup=False)

fig, ax = plt.subplots()
im = phase_plot(r, ax, domain=[-10, 10, -10, 10])
plot_poles_zeros(r, ax)
ax.legend()
fig.colorbar(im)

# %% [markdown]
# ## Reference Problem 6:
#
# \begin{equation}
# f(z) = (z - 1)(z - 2)(z - 3)(z - 4)(z - 5)(z - 6)(z - 7)(z - 8)(z - 9)(z - 10)
# \end{equation}
#
# Original function:

# %%
fig, ax = plt.subplots()
im = phase_plot(reference_problems.func5, ax, domain=[0, 12, -6, 6])
fig.colorbar(im)

# %% [markdown]
# Now compare against AAA approximation:

# %%
Z = np.linspace(-5, 5, N)
F = reference_problems.func5(Z)

r = AAA(F, Z, cleanup=False)

fig, ax = plt.subplots()
im = phase_plot(r, ax, domain=[0, 12, -6, 6])
plot_poles_zeros(r, ax, expected_zeros=list(range(1, 11)))
ax.legend()
fig.colorbar(im)
