# %%
import matplotlib.pyplot as plt

from poles_roots.global_zero_pole import find_zeros_poles
from poles_roots import reference_problems
from poles_roots.plotting import phase_plot, plot_poles_zeros

# %% [markdown]
# ## Reference Problem 1:
#
# \begin{equation}
# f(z) = \frac{1}{z - 0.5}
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func0,
    reference_problems.func0_jac,
    initial_points=[-10 - 10j, 10 - 10j, 10 + 10j, -10 + 10j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func0, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func0, axs[1], domain=[-11, 11, -11, 11])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()

# %% [markdown]
# ## Reference Problem 2:
#
# \begin{equation}
# f(z) = z-2
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func1,
    reference_problems.func1_jac,
    initial_points=[-10 - 10j, 10 - 10j, 10 + 10j, -10 + 10j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func1, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func1, axs[1], domain=[-11, 11, -11, 11])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()

# %% [markdown]
# ## Reference Problem 3:
#
# \begin{equation}
# f(z) = \exp(3z) + 2z\cos(z) - 1
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func2,
    reference_problems.func2_jac,
    initial_points=[-10 - 10j, 10 - 10j, 10 + 10j, -10 + 10j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func2, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func2, axs[1], domain=[-10, 10, -10, 10])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()

# %% [markdown]
# ## Reference Problem 4:
#
# \begin{equation}
# f(z) = z^2(z - 1)(z - 2)(z - 3)(z - 4) + z\sin(z)
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func3,
    reference_problems.func3_jac,
    initial_points=[-10 - 10j, 10 - 10j, 10 + 10j, -10 + 10j],
    arg_principal_threshold=2.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func3, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func3, axs[1], domain=[-10, 10, -10, 10])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()

# %% [markdown]
# ## Reference Problem 5:
#
# \begin{equation}
# f(z) = z^2(z - 2)^2(z^3 + \exp(2z)\cos(z) - \sin(z) - 1)
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func4,
    reference_problems.func4_jac,
    initial_points=[-10 - 10j, 10 - 10j, 10 + 10j, -10 + 10j],
    arg_principal_threshold=4.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func4, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func4, axs[1], domain=[-10, 10, -10, 10])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()
# Out:
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(1.0000000000000102+0j)
# AAA and argument principle don't match: aaa_z_minus_p=3, arg_princ_z_minus_p=(0.9999999999999991+5.332376779391653e-15j)
# AAA and argument principle don't match: aaa_z_minus_p=0, arg_princ_z_minus_p=(1.000000000000001-5.329070518200751e-15j)
# AAA and argument principle don't match: aaa_z_minus_p=3, arg_princ_z_minus_p=(9.769962616701378e-15-3.993496627459662e-15j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-4.440892098500626e-16+0j)
# AAA and argument principle don't match: aaa_z_minus_p=9, arg_princ_z_minus_p=(-4.163336342344337e-16-4.440892098500626e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=8.91484680891027e-16j
# AAA and argument principle don't match: aaa_z_minus_p=8, arg_princ_z_minus_p=(-1.1102230246251565e-16-4.440892098500626e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=-4.440892098500626e-16j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-3.0531133177191805e-16-8.881784197001252e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=4, arg_princ_z_minus_p=(4.440892098500626e-16-2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=8, arg_princ_z_minus_p=(-1.1102230246251565e-16-2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=8, arg_princ_z_minus_p=0j
# AAA and argument principle don't match: aaa_z_minus_p=3, arg_princ_z_minus_p=(0.9999999999999987+0j)
# AAA and argument principle don't match: aaa_z_minus_p=8, arg_princ_z_minus_p=(-5.551115123125783e-17-1.7763568394002505e-15j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(6.440160904563896e-17+2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=9, arg_princ_z_minus_p=(4.440892098500626e-16-4.440892098500626e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(8.881784197001252e-16-3.1086244689504383e-15j)
# AAA and argument principle don't match: aaa_z_minus_p=7, arg_princ_z_minus_p=(-5.551115123125783e-17-2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=5, arg_princ_z_minus_p=(2.220446049250313e-16+0j)
# AAA and argument principle don't match: aaa_z_minus_p=8, arg_princ_z_minus_p=(-1.6653345369377348e-16-8.881784197001252e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=7, arg_princ_z_minus_p=(-7.771561172376096e-16+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.021405182655144e-14+0j)
# AAA and argument principle don't match: aaa_z_minus_p=9, arg_princ_z_minus_p=0j
# AAA and argument principle don't match: aaa_z_minus_p=10, arg_princ_z_minus_p=2.220446049250313e-16j
# AAA and argument principle don't match: aaa_z_minus_p=7, arg_princ_z_minus_p=(5.551115123125783e-17+4.440892098500626e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=9, arg_princ_z_minus_p=(4.440892098500626e-16+2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=6, arg_princ_z_minus_p=(2.220446049250313e-16+0j)
# AAA and argument principle don't match: aaa_z_minus_p=6, arg_princ_z_minus_p=(-1.1102230246251565e-16-3.3306690738754696e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.1102230246251565e-16-4.440892098500626e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=7, arg_princ_z_minus_p=(-1.6653345369377348e-16-4.440892098500626e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(7.993605777301127e-15-1.7763568394002505e-15j)
# AAA and argument principle don't match: aaa_z_minus_p=9, arg_princ_z_minus_p=(4.440892098500626e-16-4.440892098500626e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=7, arg_princ_z_minus_p=(-4.440892098500626e-16-2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=8, arg_princ_z_minus_p=(-1.1102230246251565e-16+0j)
# AAA and argument principle don't match: aaa_z_minus_p=8, arg_princ_z_minus_p=0j
# AAA and argument principle don't match: aaa_z_minus_p=7, arg_princ_z_minus_p=(2.7755575615628914e-17-4.440892098500626e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=6, arg_princ_z_minus_p=(5.551115123125783e-17+2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=5, arg_princ_z_minus_p=-2.220446049250313e-16j
# AAA and argument principle don't match: aaa_z_minus_p=6, arg_princ_z_minus_p=(-1.1102230246251565e-16+1.1102230246251565e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(5.551115123125783e-17-5.551115123125783e-17j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.3877787807814457e-17+0j)
# AAA and argument principle don't match: aaa_z_minus_p=4, arg_princ_z_minus_p=(8.326672684688674e-17-2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=6, arg_princ_z_minus_p=(-8.881784197001252e-16+0j)
# AAA and argument principle don't match: aaa_z_minus_p=7, arg_princ_z_minus_p=(1.1102230246251565e-16-2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=9, arg_princ_z_minus_p=(4.440892098500626e-16-2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=6, arg_princ_z_minus_p=(-2.7755575615628914e-17-1.1102230246251565e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=6, arg_princ_z_minus_p=(-2.220446049250313e-16+2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=6, arg_princ_z_minus_p=1.1102230246251565e-16j
# AAA and argument principle don't match: aaa_z_minus_p=6, arg_princ_z_minus_p=-2.220446049250313e-16j
# AAA and argument principle don't match: aaa_z_minus_p=8, arg_princ_z_minus_p=(1.1102230246251565e-16+0j)
# AAA and argument principle don't match: aaa_z_minus_p=6, arg_princ_z_minus_p=-2.220446049250313e-16j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=2.7755575615628914e-17j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=0j
# AAA and argument principle don't match: aaa_z_minus_p=3, arg_princ_z_minus_p=-2.7755575615628914e-17j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(5.551115123125783e-17+5.551115123125783e-17j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-3.469446951953614e-18-1.1102230246251565e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=3, arg_princ_z_minus_p=(1.4224732503009818e-16-1.3877787807814457e-17j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-1.1102230246251565e-16+0j)
# AAA and argument principle don't match: aaa_z_minus_p=7, arg_princ_z_minus_p=(8.326672684688674e-17-2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=7, arg_princ_z_minus_p=(-4.440892098500626e-16+0j)
# AAA and argument principle don't match: aaa_z_minus_p=8, arg_princ_z_minus_p=(-8.881784197001252e-16+2.220446049250313e-16j)
# AAA and argument principle don't match: aaa_z_minus_p=5, arg_princ_z_minus_p=
8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.0842021724855044e-19+1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.673617379884035e-19-1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(2.168404344971009e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-1.6479873021779667e-17-6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=6.938893903907228e-18j
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-5.204170427930421e-18+8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(6.938893903907228e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(6.938893903907228e-18-1.3010426069826053e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-3.469446951953614e-18+2.6020852139652106e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-3.469446951953614e-18+6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.734723475976807e-18+3.469446951953614e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-3.469446951953614e-18+6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-1.734723475976807e-18-1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=1.81603863891322e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(3.469446951953614e-18-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-1.734723475976807e-18-1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-3.469446951953614e-18+5.854691731421724e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-5.421010862427522e-18-6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(6.938893903907228e-18+3.469446951953614e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(6.938893903907228e-18-1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-3.469446951953614e-18-6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-6.938893903907228e-18+3.469446951953614e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-3.0357660829594124e-18+3.469446951953614e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-8.023096076392733e-18+3.469446951953614e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-1.3877787807814457e-17-6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=1.734723475976807e-18j
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-8.673617379884035e-18+6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-8.673617379884035e-18+2.0816681711721685e-17j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-1.3877787807814457e-17-3.469446951953614e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.3877787807814457e-17-3.469446951953614e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-7.806255641895632e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(6.938893903907228e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-1.214306433183765e-17-1.3877787807814457e-17j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=-1.3877787807814457e-17j
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(8.456776945386935e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.3877787807814457e-17+6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=0j
# AAA and argument principle don't match: aaa_z_minus_p=3, arg_princ_z_minus_p=-1.3877787807814457e-17j
# AAA and argument principle don't match: aaa_z_minus_p=3, arg_princ_z_minus_p=(-6.938893903907228e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-6.938893903907228e-18+6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=-3.469446951953614e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.734723475976807e-18+3.469446951953614e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-2.5478751053409354e-18-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(3.469446951953614e-18-2.168404344971009e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.734723475976807e-18-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.3010426069826053e-18+8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(8.673617379884035e-19+3.903127820947816e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=-5.204170427930421e-18j
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=3.469446951953614e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.734723475976807e-18+1.951563910473908e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.734723475976807e-18-9.75781955236954e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-6.938893903907228e-18+1.3010426069826053e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=-3.903127820947816e-18j
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(6.938893903907228e-18-5.204170427930421e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=-1.734723475976807e-18j
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=0j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.3010426069826053e-18-4.336808689942018e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=0j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.673617379884035e-19-1.0842021724855044e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.734723475976807e-18-1.3877787807814457e-17j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(1.1384122811097797e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(8.673617379884035e-18+6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-6.938893903907228e-18+3.469446951953614e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(6.938893903907228e-18-1.3877787807814457e-17j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-6.938893903907228e-18+1.0408340855860843e-17j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(6.938893903907228e-18+6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-5.204170427930421e-18+0j)
# ...
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(8.673617379884035e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(3.469446951953614e-18-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.734723475976807e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=1.734723475976807e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.673617379884035e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(8.673617379884035e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.734723475976807e-18-1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=0j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=1.734723475976807e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.673617379884035e-19-3.2526065174565133e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=0j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(8.673617379884035e-19+1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=1.734723475976807e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(4.336808689942018e-19-4.336808689942018e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=-8.673617379884035e-19j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.0842021724855044e-19-3.469446951953614e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.734723475976807e-18+2.168404344971009e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-3.469446951953614e-18-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.3010426069826053e-18+1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-2.168404344971009e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-3.469446951953614e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=3.469446951953614e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.734723475976807e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.734723475976807e-18-1.0842021724855044e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.673617379884035e-19-6.505213034913027e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(4.336808689942018e-19-1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.673617379884035e-19+4.336808689942018e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=-4.336808689942018e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.734723475976807e-18+6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-2.710505431213761e-20-1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.734723475976807e-18-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.734723475976807e-18+8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=-1.6263032587282567e-19j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(8.673617379884035e-19-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(4.336808689942018e-19-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.673617379884035e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(4.336808689942018e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.7618285302889447e-19-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(8.673617379884035e-19+2.168404344971009e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-1.0408340855860843e-17-6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-6.938893903907228e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(1.3877787807814457e-17+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=8.673617379884035e-19j
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=-3.469446951953614e-18j
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(6.938893903907228e-18-6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(6.938893903907228e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-3.469446951953614e-18-6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(3.469446951953614e-18+6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(5.204170427930421e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-1.734723475976807e-18+6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.0842021724855044e-18-1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(8.673617379884035e-19+1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.673617379884035e-19-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(8.673617379884035e-19+1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.131516293641283e-19+8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-2.6020852139652106e-18-1.3010426069826053e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=-2.168404344971009e-19j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(2.6020852139652106e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=0j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.673617379884035e-19-4.336808689942018e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.673617379884035e-19+1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(4.336808689942018e-19-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.5178830414797062e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.673617379884035e-19-1.3010426069826053e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.734723475976807e-18-1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=1.734723475976807e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=4.336808689942018e-19j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-2.168404344971009e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-4.336808689942018e-19-1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-3.2526065174565133e-19+8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.6263032587282567e-19+1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(8.673617379884035e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=2.168404344971009e-19j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=0j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-8.673617379884035e-19+5.421010862427522e-20j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(2.168404344971009e-19+4.336808689942018e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.734723475976807e-18+1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=1.734723475976807e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.734723475976807e-18-2.6020852139652106e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.111307226797642e-18+1.734723475976807e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.734723475976807e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(3.469446951953614e-18-6.938893903907228e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.3877787807814457e-17-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-6.938893903907228e-18+3.469446951953614e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-9.540979117872439e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-3.469446951953614e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(3.469446951953614e-18+6.071532165918825e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(-1.734723475976807e-18-3.469446951953614e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-1.734723475976807e-18-2.6020852139652106e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(2.6020852139652106e-18+1.6263032587282567e-18j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(4.336808689942018e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-3.469446951953614e-18+1.4230153513872246e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(-4.336808689942018e-19+4.336808689942018e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=6.938893903907228e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=1.734723475976807e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(5.421010862427522e-19-8.673617379884035e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=-4.336808689942018e-19j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(4.336808689942018e-19+2.168404344971009e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(2.168404344971009e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(2.168404344971009e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(2.168404344971009e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(8.673617379884035e-19-1.6263032587282567e-19j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(1.734723475976807e-18+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=0j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(4.336808689942018e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=-2.6020852139652106e-18j
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(8.673617379884035e-19+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(2.656295322589486e-18+3.469446951953614e-18j)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 res = find_zeros_poles(
#       2     reference_problems.func4,
#       3     reference_problems.func4_jac,
#       4     initial_points=[-10 - 10j, 10 - 10j, 10 + 10j, -10 + 10j],
#       5     arg_principal_threshold=4.1,
#       6     num_sample_points=50,
#       7 )
#       9 fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
#      10 phase_plot(reference_problems.func4, axs[0], domain=[-10, 10, -10, 10])
#
# File ~/development/poles-and-roots/src/poles_roots/global_zero_pole.py:93, in find_zeros_poles(f, f_jac, initial_points, num_sample_points, arg_principal_threshold, quad_kwargs, plot_triangulation, plot_aaa)
#      90 # function values
#      91 F = f(z)
# ---> 93 aaa_res = AAA(F, z)
#      95 if plot_aaa:
#      96     fig, ax = plt.subplots()
#
# File ~/development/poles-and-roots/src/poles_roots/aaa.py:173, in AAA(F, Z, tol, mmax, cleanup, cleanup_tol)
#     171 if cleanup:
#     172     wj, zj, fj, Z, F = _clean_up(pol, res, wj, zj, fj, Z, F, cleanup_tol)
# --> 173     pol, res, zer = _prz(zj, fj, wj)
#     175 return _AAAResult(pol, res, zer, zj, fj, wj, errvec)
#
# File ~/development/poles-and-roots/src/poles_roots/aaa.py:205, in _prz(zj, fj, wj)
#     202 E[1:, 0] = 1
#     203 np.fill_diagonal(E[1:, 1:], zj)
# --> 205 zer = scipy.linalg.eigvals(E, B)
#     206 zer = zer[np.isfinite(zer)]
#     208 return pol, res, zer
#
# File ~/development/poles-and-roots/venv/lib/python3.12/site-packages/scipy/linalg/_decomp.py:896, in eigvals(a, b, overwrite_a, check_finite, homogeneous_eigvals)
#     826 def eigvals(a, b=None, overwrite_a=False, check_finite=True,
#     827             homogeneous_eigvals=False):
#     828     """
#     829     Compute eigenvalues from an ordinary or generalized eigenvalue problem.
#     830
#    (...)
#     894
#     895     """
# --> 896     return eig(a, b=b, left=0, right=0, overwrite_a=overwrite_a,
#     897                check_finite=check_finite,
#     898                homogeneous_eigvals=homogeneous_eigvals)
#
# File ~/development/poles-and-roots/venv/lib/python3.12/site-packages/scipy/linalg/_decomp.py:215, in eig(a, b, left, right, overwrite_a, overwrite_b, check_finite, homogeneous_eigvals)
#     117 def eig(a, b=None, left=False, right=True, overwrite_a=False,
#     118         overwrite_b=False, check_finite=True, homogeneous_eigvals=False):
#     119     """
#     120     Solve an ordinary or generalized eigenvalue problem of a square matrix.
#     121
#    (...)
#     213
#     214     """
# --> 215     a1 = _asarray_validated(a, check_finite=check_finite)
#     216     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     217         raise ValueError('expected square matrix')
#
# File ~/development/poles-and-roots/venv/lib/python3.12/site-packages/scipy/_lib/_util.py:321, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     319         raise ValueError('masked arrays are not supported')
#     320 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 321 a = toarray(a)
#     322 if not objects_ok:
#     323     if a.dtype is np.dtype('O'):
#
# File ~/development/poles-and-roots/venv/lib/python3.12/site-packages/numpy/lib/function_base.py:629, in asarray_chkfinite(a, dtype, order)
#     566 """Convert the input to an array, checking for NaNs or Infs.
#     567
#     568 Parameters
#    (...)
#     626
#     627 """
#     628 a = asarray(a, dtype=dtype, order=order)
# --> 629 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     630     raise ValueError(
#     631         "array must not contain infs or NaNs")
#     632 return a
#
# KeyboardInterrupt:

# %% [markdown]
# ## Reference Problem 6:
#
# \begin{equation}
# f(z) = (z - 1)(z - 2)(z - 3)(z - 4)(z - 5)(z - 6)(z - 7)(z - 8)(z - 9)(z - 10)
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func5,
    reference_problems.func5_jac,
    initial_points=[-11 - 11j, 11 - 11j, 11 + 11j, -11 + 11j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func5, axs[0], domain=[-11, 11, -11, 11])
phase_plot(reference_problems.func5, axs[1], domain=[-12, 12, -12, 12])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()
# Out:
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(1.0000000000000109+0j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(4.440892098500626e-16+1.0436096431476471e-14j)
