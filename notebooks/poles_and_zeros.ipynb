# %%
import matplotlib.pyplot as plt

from poles_roots.global_zero_pole import find_zeros_poles
from poles_roots import reference_problems
from poles_roots.plotting import phase_plot, plot_poles_zeros

# %% [markdown]
# ## Reference Problem 1:
#
# \begin{equation}
# f(z) = \frac{1}{z - 0.5}
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func0,
    reference_problems.func0_jac,
    points=[-9.9 - 10j, 10 - 10j, 10 + 10j, -10 + 10j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func0, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func0, axs[1], domain=[-11, 11, -11, 11])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()

# %% [markdown]
# ## Reference Problem 2:
#
# \begin{equation}
# f(z) = z-2
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func1,
    reference_problems.func1_jac,
    points=[-9.9 - 10j, 10 - 10j, 10 + 10j, -10 + 10j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func1, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func1, axs[1], domain=[-11, 11, -11, 11])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()

# %% [markdown]
# ## Reference Problem 3:
#
# \begin{equation}
# f(z) = \exp(3z) + 2z\cos(z) - 1
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func2,
    reference_problems.func2_jac,
    points=[-9 - 9.2j, 9 - 10j, 9.9 + 9.8j, -9.3 + 9.5j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func2, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func2, axs[1], domain=[-10, 10, -10, 10])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()

# %% [markdown]
# ## Reference Problem 4:
#
# \begin{equation}
# f(z) = z^2(z - 1)(z - 2)(z - 3)(z - 4) + z\sin(z)
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func3,
    reference_problems.func3_jac,
    points=[-9 - 9.2j, 9 - 10j, 9.9 + 9.8j, -9.3 + 9.5j],
    arg_principal_threshold=2.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func3, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func3, axs[1], domain=[-10, 10, -10, 10])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()

# %% [markdown]
# ## Reference Problem 5:
#
# \begin{equation}
# f(z) = z^2(z - 2)^2(z^3 + \exp(2z)\cos(z) - \sin(z) - 1)
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func4,
    reference_problems.func4_jac,
    points=[-9 - 9.2j, 8 - 10j, 9.9 + 9.8j, -9.3 + 9.5j],
    arg_principal_threshold=4.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func4, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func4, axs[1], domain=[-10, 10, -10, 10])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()
# Out:
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(0.9397038802555282+0.3269480851759338j)
# AAA and argument principle don't match: aaa_z_minus_p=3, arg_princ_z_minus_p=(0.021864363644317875+2.469136006766348e-13j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(0.9397038802555719-0.32694808517593144j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(0.06768718962787101-2.651212582804874e-13j)
# AAA and argument principle don't match: aaa_z_minus_p=2, arg_princ_z_minus_p=(1.6037378877334052+0.868712001941089j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(0.6709594098788185+1.28287358127637j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(0.6676600629498313-0.47165683961151045j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(0.9360778247837338-0.39705516232957877j)
# AAA and argument principle don't match: aaa_z_minus_p=1, arg_princ_z_minus_p=(0.6709594098787639-1.2828735812763707j)
# AAA and argument principle don't match: aaa_z_minus_p=3, arg_princ_z_minus_p=(1.472932985682037+1.7763568394002505e-15j)
# AAA and argument principle don't match: aaa_z_minus_p=3, arg_princ_z_minus_p=(4.000000000000005+4.440892098500626e-16j)

# %% [markdown]
# ## Reference Problem 6:
#
# \begin{equation}
# f(z) = (z - 1)(z - 2)(z - 3)(z - 4)(z - 5)(z - 6)(z - 7)(z - 8)(z - 9)(z - 10)
# \end{equation}

# %%
res = find_zeros_poles(
    reference_problems.func5,
    reference_problems.func5_jac,
    points=[-9 - 9.2j, 8 - 10j, 9.9 + 9.8j, -9.3 + 9.5j],
    arg_principal_threshold=1.1,
    num_sample_points=50,
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 6))
phase_plot(reference_problems.func5, axs[0], domain=[-10, 10, -10, 10])
phase_plot(reference_problems.func5, axs[1], domain=[-10, 10, -10, 10])
plot_poles_zeros(res, axs[0])
axs[0].legend()
axs[1].triplot(res.points[:, 0], res.points[:, 1], res.simplices)
plt.show()
